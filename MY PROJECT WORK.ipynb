# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df = pd.read_csv('tmdb-movies.csv', index_col=0)
df.head()
# Out:
#           imdb_id  popularity     budget     revenue  \
# id
# 135397  tt0369610   32.985763  150000000  1513528810
# 76341   tt1392190   28.419936  150000000   378436354
# 262500  tt2908446   13.112507  110000000   295238201
# 140607  tt2488496   11.173104  200000000  2068178225
# 168259  tt2820852    9.335014  190000000  1506249360
#
#                       original_title  \
# id
# 135397                Jurassic World
# 76341             Mad Max: Fury Road
# 262500                     Insurgent
# 140607  Star Wars: The Force Awakens
# 168259                     Furious 7
#
#                                                      cast  \
# id
# 135397  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 76341   Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 262500  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 140607  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 168259  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
# ...

# %%
df = pd.read_csv('tmdb-movies.csv', usecols = ['budget', 'revenue', 'original_title', 'genres', 'release_year'], index_col=0)
df.head()
# Out:
#               revenue                original_title  \
# budget
# 150000000  1513528810                Jurassic World
# 150000000   378436354            Mad Max: Fury Road
# 110000000   295238201                     Insurgent
# 200000000  2068178225  Star Wars: The Force Awakens
# 190000000  1506249360                     Furious 7
#
#                                               genres  release_year
# budget
# 150000000  Action|Adventure|Science Fiction|Thriller          2015
# 150000000  Action|Adventure|Science Fiction|Thriller          2015
# 110000000         Adventure|Science Fiction|Thriller          2015
# 200000000   Action|Adventure|Science Fiction|Fantasy          2015
# 190000000                      Action|Crime|Thriller          2015

# %%
df.isnull().sum()
# Out:
# revenue           0
# original_title    0
# genres            0
# release_year      0
# dtype: int64

# %%
df = pd.read_csv('tmdb-movies.csv', usecols = ['budget', 'revenue', 'original_title', 'genres', 'release_year'], index_col=0)
df.head()
# Out:
#               revenue                original_title  \
# budget
# 150000000  1513528810                Jurassic World
# 150000000   378436354            Mad Max: Fury Road
# 110000000   295238201                     Insurgent
# 200000000  2068178225  Star Wars: The Force Awakens
# 190000000  1506249360                     Furious 7
#
#                                               genres  release_year
# budget
# 150000000  Action|Adventure|Science Fiction|Thriller          2015
# 150000000  Action|Adventure|Science Fiction|Thriller          2015
# 110000000         Adventure|Science Fiction|Thriller          2015
# 200000000   Action|Adventure|Science Fiction|Fantasy          2015
# 190000000                      Action|Crime|Thriller          2015

# %%
df.to_csv('project.csv')

# %%
df2 = pd.read_csv('project.csv')
df2
# Out:
#           budget     revenue                original_title  \
# 0      150000000  1513528810                Jurassic World
# 1      150000000   378436354            Mad Max: Fury Road
# 2      110000000   295238201                     Insurgent
# 3      200000000  2068178225  Star Wars: The Force Awakens
# 4      190000000  1506249360                     Furious 7
# ...          ...         ...                           ...
# 10861          0           0            The Endless Summer
# 10862          0           0                    Grand Prix
# 10863          0           0           Beregis Avtomobilya
# 10864          0           0        What's Up, Tiger Lily?
# 10865      19000           0      Manos: The Hands of Fate
#
#                                           genres  release_year
# 0      Action|Adventure|Science Fiction|Thriller          2015
# 1      Action|Adventure|Science Fiction|Thriller          2015
# 2             Adventure|Science Fiction|Thriller          2015
# ...

# %%
df2 = pd.read_csv('project.csv')
df2.head(5000)
# Out:
#          budget     revenue                         original_title  \
# 0     150000000  1513528810                         Jurassic World
# 1     150000000   378436354                     Mad Max: Fury Road
# 2     110000000   295238201                              Insurgent
# 3     200000000  2068178225           Star Wars: The Force Awakens
# 4     190000000  1506249360                              Furious 7
# ...         ...         ...                                    ...
# 4995   45000000   124914842  Legally Blonde 2: Red, White & Blonde
# 4996          0           0                Atlantis: Milo's Return
# 4997          0           0                     The Cat in the Hat
# 4998   26000000   110230332                          Freaky Friday
# 4999   60000000    26288320       Sinbad: Legend of the Seven Seas
#
#                                                genres  release_year
# 0           Action|Adventure|Science Fiction|Thriller          2015
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   budget          10866 non-null  int64
#  1   revenue         10866 non-null  int64
#  2   original_title  10866 non-null  object
#  3   genres          10843 non-null  object
#  4   release_year    10866 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 424.6+ KB

# %%
df2.groupby('budget')['budget'].agg("count")
# Out:
# budget
# 0            5696
# 1               4
# 2               1
# 3               3
# 5               1
#              ...
# 270000000       1
# 280000000       1
# 300000000       1
# 380000000       1
# 425000000       1
# Name: budget, Length: 557, dtype: int64

# %%
df2.groupby('revenue')['revenue'].agg("count")
# Out:
# revenue
# 0             6016
# 2                2
# 3                3
# 5                2
# 6                2
#               ...
# 1513528810       1
# 1519557910       1
# 1845034188       1
# 2068178225       1
# 2781505847       1
# Name: revenue, Length: 4702, dtype: int64

# %%
mean_v=df2['budget'].mean()

# %%
mean_v
# Out:
# 14625701.09414688

# %%
df2.groupby('genres')['genres'].agg("count")
# Out:
# genres
# Action                                      63
# Action|Adventure                            15
# Action|Adventure|Animation                   4
# Action|Adventure|Animation|Comedy|Drama      1
# Action|Adventure|Animation|Comedy|Family     1
#                                             ..
# Western|Drama|Crime|Romance                  1
# Western|History                              1
# Western|History|War                          1
# Western|Horror|Thriller                      1
# Western|Thriller                             1
# Name: genres, Length: 2039, dtype: int64

# %%
df3 = df2.drop_duplicates(subset='budget', keep= False)
df3.head()
# Out:
#        budget     revenue                original_title  \
# 7   108000000   595380321                   The Martian
# 10  245000000   880674609                       Spectre
# 11  176000003   183987723             Jupiter Ascending
# 14  280000000  1405035767       Avengers: Age of Ultron
# 27   81000000   403802136  Kingsman: The Secret Service
#
#                                       genres  release_year
# 7            Drama|Adventure|Science Fiction          2015
# 10                    Action|Adventure|Crime          2015
# 11  Science Fiction|Fantasy|Action|Adventure          2015
# 14          Action|Adventure|Science Fiction          2015
# 27             Crime|Comedy|Action|Adventure          2015

# %%
df4 = df3.drop_duplicates(subset='revenue', keep=False)
df4.head(5000)
# Out:
#           budget     revenue                original_title  \
# 7      108000000   595380321                   The Martian
# 10     245000000   880674609                       Spectre
# 11     176000003   183987723             Jupiter Ascending
# 14     280000000  1405035767       Avengers: Age of Ultron
# 27      81000000   403802136  Kingsman: The Secret Service
# ...          ...         ...                           ...
# 10656   25485000    29548291             Tora! Tora! Tora!
# 10675    3716946     3500000     The Ballad of Cable Hogue
# 10728    6244087      638641                The Wild Bunch
# 10775    7920000    14560084             Death on the Nile
# 10848    5115000    12000000              Fantastic Voyage
#
#                                          genres  release_year
# 7               Drama|Adventure|Science Fiction          2015
# 10                       Action|Adventure|Crime          2015
# 11     Science Fiction|Fantasy|Action|Adventure          2015
# ...

# %%
df4.groupby('revenue')['revenue'].agg("count")
# Out:
# revenue
# 15            1
# 16            1
# 42            1
# 134           1
# 193           1
#              ..
# 961000000     1
# 1021683000    1
# 1405035767    1
# 1519557910    1
# 2781505847    1
# Name: revenue, Length: 180, dtype: int64

# %%
df4.describe()
# Out:
#              budget       revenue  release_year
# count  1.800000e+02  1.800000e+02    180.000000
# mean   4.482970e+07  1.356455e+08   2000.727778
# std    7.588723e+07  3.141018e+08     13.331540
# min    2.000000e+00  1.500000e+01   1960.000000
# 25%    1.960739e+06  3.360296e+06   1993.750000
# 50%    1.209000e+07  1.990218e+07   2005.000000
# 75%    4.995000e+07  1.141686e+08   2011.000000
# max    4.250000e+08  2.781506e+09   2015.000000

# %%
sns.distplot(df4["budget"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13324\3240786913.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4["budget"])
# <Axes: xlabel='budget', ylabel='Density'>

# %%
sns.displot(df4["revenue"])
# Out:
# C:\Users\DELL\anaconda33\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
Q1 = df4.budget.quantile(0.25)
Q3 = df4.budget.quantile(0.7)
Q1, Q3
# Out:
# (1960739.0, 31754999.999999996)

# %%
IQR = Q3-Q1
IQR
# Out:
# 29794260.999999996

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (-42730652.49999999, 76446391.49999999)

# %%
df4[(df4.budget<lower_limit)|(df4.budget>upper_limit)]
# Out:
#          budget     revenue                                original_title  \
# 7     108000000   595380321                                   The Martian
# 10    245000000   880674609                                       Spectre
# 11    176000003   183987723                             Jupiter Ascending
# 14    280000000  1405035767                       Avengers: Age of Ultron
# 27     81000000   403802136                  Kingsman: The Secret Service
# 61    120000001   167977596                                Fantastic Four
# 76     99000000   246233113                             The Peanuts Movie
# 641   127000000   349424282       Night at the Museum: Secret of the Tomb
# 655   178000000   370541256                              Edge of Tomorrow
# 1386  237000000  2781505847                                        Avatar
# 1569   78146652    60000000                                     Duplicity
# 1971  117000000   261930431                                Knight and Day
# ...

# %%
df4_no_outlier = df4[(df4.budget>lower_limit)&(df4.budget<upper_limit)]
df4_no_outlier
# Out:
#          budget    revenue             original_title  \
# 50     11800000   40272135                      Carol
# 64     50100000  153962963                      Focus
# 96     11930000   18340000             The Dressmaker
# 109     8900000      50136                      Heist
# 123    14800000  122413057             Magic Mike XXL
# ...         ...        ...                        ...
# 10656  25485000   29548291          Tora! Tora! Tora!
# 10675   3716946    3500000  The Ballad of Cable Hogue
# 10728   6244087     638641             The Wild Bunch
# 10775   7920000   14560084          Death on the Nile
# 10848   5115000   12000000           Fantastic Voyage
#
#                                    genres  release_year
# 50                          Romance|Drama          2015
# 64             Romance|Comedy|Crime|Drama          2015
# 96                                  Drama          2015
# 109                 Crime|Action|Thriller          2015
# ...

# %%
df5 = df4_no_outlier
df5.head()
# Out:
#        budget    revenue  original_title                      genres  \
# 50   11800000   40272135           Carol               Romance|Drama
# 64   50100000  153962963           Focus  Romance|Comedy|Crime|Drama
# 96   11930000   18340000  The Dressmaker                       Drama
# 109   8900000      50136           Heist       Crime|Action|Thriller
# 123  14800000  122413057  Magic Mike XXL          Comedy|Drama|Music
#
#      release_year
# 50           2015
# 64           2015
# 96           2015
# 109          2015
# 123          2015

# %%
df5_no_outlier = df4[(df4.revenue>lower_limit)&(df4.revenue<upper_limit)]
df5_no_outlier
# Out:
#          budget   revenue             original_title  \
# 50     11800000  40272135                      Carol
# 96     11930000  18340000             The Dressmaker
# 109     8900000     50136                      Heist
# 304      447524    771317                The D Train
# 756    12250000   2295423                  The Rover
# ...         ...       ...                        ...
# 10656  25485000  29548291          Tora! Tora! Tora!
# 10675   3716946   3500000  The Ballad of Cable Hogue
# 10728   6244087    638641             The Wild Bunch
# 10775   7920000  14560084          Death on the Nile
# 10848   5115000  12000000           Fantastic Voyage
#
#                                    genres  release_year
# 50                          Romance|Drama          2015
# 96                                  Drama          2015
# 109                 Crime|Action|Thriller          2015
# 304                          Drama|Comedy          2015
# ...

# %%
df6 = df5_no_outlier = df4[(df4.revenue>lower_limit)&(df4.revenue<upper_limit)]
df6.head(5000)
# Out:
#          budget   revenue             original_title  \
# 50     11800000  40272135                      Carol
# 96     11930000  18340000             The Dressmaker
# 109     8900000     50136                      Heist
# 304      447524    771317                The D Train
# 756    12250000   2295423                  The Rover
# ...         ...       ...                        ...
# 10656  25485000  29548291          Tora! Tora! Tora!
# 10675   3716946   3500000  The Ballad of Cable Hogue
# 10728   6244087    638641             The Wild Bunch
# 10775   7920000  14560084          Death on the Nile
# 10848   5115000  12000000           Fantastic Voyage
#
#                                    genres  release_year
# 50                          Romance|Drama          2015
# 96                                  Drama          2015
# 109                 Crime|Action|Thriller          2015
# 304                          Drama|Comedy          2015
# ...
